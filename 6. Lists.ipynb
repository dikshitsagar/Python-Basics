# %% [markdown]
# # Lists

# %%
# check the length of the lists
mylist = [1,2,3,'hello','wissen']
print(len(mylist))
# len(list_name)
# Out:
# 5

# %%
# print value in the list
for i in mylist:
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# print values in the list using comphernsion
[i for i in mylist]
# Out:
# [1, 2, 3, 'hello', 'wissen']

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mylist2 = ['a','b','c','d','e']

# %%
# reverse the list and print last value
mylist2_revers = mylist2[::-1]
print(mylist2_revers)

# list[start:end:step]
# list[:]
# Out:
# ['e', 'd', 'c', 'b', 'a']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mylist2[0:]
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
mylist2[1:]
# Out:
# ['b', 'c', 'd', 'e']

# %%
mylist2[:3]
# Out:
# ['a', 'b', 'c']

# %%
mylist2[-1:]
# Out:
# ['e']

# %%
mylist2[-2:]
# Out:
# ['d', 'e']

# %%
mylist2[:-1]
# Out:
# ['a', 'b', 'c', 'd']

# %%
mylist2
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
# append value to exixsting list
mylist2.append('w')
print(mylist2)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'w', 'w']

# %%
# append sub list to a list
mylist2.append(['g','h','i'])
print(mylist2)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', ['g', 'h', 'i']]

# %%
# append function appends multiple values as a sub - list
mylist2.append(['do','uy'])

# %%
mylist2
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', ['g', 'h', 'i'], ['do', 'uy']]

# %%
help(mylist2.extend)
# Out:
# Help on built-in function extend:
#
# extend(iterable, /) method of builtins.list instance
#     Extend list by appending elements from the iterable.

# %%
# extend list by appending elements from the iterable 
#append adds an element to a list, and extend concatenates the first list with another list (or another iterable, not necessarily a list.)
mylist2.extend(['g','h','i'])

# %%
print(mylist2)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'w', 'w', 'g', 'h', 'i']

# %%
item1 = mylist2.pop()
print(item1)
# it poped out last element
# Out:
# i

# %%
item2 = mylist2.pop(2)
print(item2)
# pop's out the 0th index
# Out:
# c

# %%
mylist2
# Out:
# ['a', 'b', 'd', 'e', 'w', 'w', 'g', 'h']

# %%
mylist2.index('h')
# prints the index of the value
# Out:
# 7

# %%
print(mylist2.reverse())
# Out:
# None

# %%
mylist3 = ['a','b','c']
print(mylist3)
# Out:
# ['a', 'b', 'c']

# %%
print(mylist3.reverse())
# Out:
# None

# %%
mylist4 = [1,2,3,'wissen']
mylist4
# Out:
# [1, 2, 3, 'wissen']

# %%
mylist4.reverse()

# %%
print(mylist4)
# reverse() modifies List in place. As a general rule, Python builtin methods will either mutate or return something but not both
# Out:
# ['wissen', 3, 2, 1]

# %%
mylist3
# Out:
# ['c', 'b', 'a']

# %%
mylist3[::-1] # another option
# Out:
# ['a', 'b', 'c']

# %%
mylist4[::-1]
# Out:
# [1, 2, 3, 'wissen']
